# %% [markdown]
# # Proyek Analisis Data: E-commerce Public Dataset
#
# - **Nama:** Vanessa Leonora
# - **Email:** vanessaleonora02@gmail.com
# - **ID Dicoding:** vanessa_leonora_24

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak dan paling sedikit terjual ?
#
# - Bagaimana demografi pelanggan yang Kita miliki ?
#
# - Metode pembayaran apa yang paling sering dan sedikit digunakan ?
#
# - Bagaimana performa penjualan dan revenue perusahaan per bulan (2016 - 2018) ?
#
# - Bagaimana tingkat kepuasan pengguna terhadap layanan yang diberikan ?
#
#
#
# Analisis Lanjutan (Opsional) :
#
# - Kapan terakhir pelanggan melakukan transaksi ?
#
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir ?
#
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Memuat tabel customers

# %%
customers_df = pd.read_csv('dataset/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Memuat tabel geolocation

# %%
geoloc_df = pd.read_csv('dataset/geolocation_dataset.csv')
geoloc_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# Memuat tabel order items

# %%
order_items_df = pd.read_csv('dataset/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# Memuat tabel order payments

# %%
order_payments_df = pd.read_csv('dataset/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Memuat tabel order reviews

# %%
order_reviews_df = pd.read_csv('dataset/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# Memuat tabel orders

# %%
orders_df = pd.read_csv('dataset/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Memuat tabel product category

# %%
product_category_df = pd.read_csv('dataset/product_category_name_translation.csv')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# Memuat tabel products

# %%
products_df = pd.read_csv('dataset/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Memuat tabel sellers

# %%
sellers_df = pd.read_csv('dataset/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai data customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Mengecek adanya missing value pada customers_df

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Mengecek adanya duplikasi data pada customers_df

# %%
print("Jumlah duplikasi data pada customers_df: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada customers_df:  0

# %% [markdown]
# Menampilkan ringkasan paramter statistik (mean, median, dll)

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# Menilai data geolocation

# %%
geoloc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# Mengecek adanya duplikasi data pada geoloc_df

# %%
print("Jumlah duplikasi data pada geoloc_df: ", geoloc_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada geoloc_df:  261831

# %% [markdown]
# Menampilkan ringkasan parameter statistik geoloc_df

# %%
geoloc_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# Menilai data order items

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Mengecek adanya duplikasi data pada order_items_df

# %%
print("Jumlah duplikasi data pada order_items_df: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada order_items_df:  0

# %% [markdown]
# Menampilkan ringkasan parameter statistik pada order_items_df

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# Menilai data order payments

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik order_payments_df

# %%
print("Jumlah duplikasi data pada order_payments_df: ", order_payments_df.duplicated().sum())
order_payments_df.describe()
# Out:
# Jumlah duplikasi data pada order_payments_df:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# Menilai data order reviews

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Mengecek adanya missing value pada order_reviews_df

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik order_reviews_df

# %%
print("Jumlah duplikasi data pada order_reviews_df: ", order_reviews_df.duplicated().sum())

order_reviews_df.describe()
# Out:
# Jumlah duplikasi data pada order_reviews_df:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# Menilai data orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Mengecek adanya missing value pada orders_df

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik orders_df

# %%
print("Jumlah duplikasi data pada orders_df: ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi data pada orders_df:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# Menilai data product category

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik product_category_df

# %%
print("Jumlah duplikasi data pada product_category_df: ", product_category_df.duplicated().sum())
product_category_df.describe()
# Out:
# Jumlah duplikasi data pada product_category_df:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# Menilai data products

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Mengecek adanya missing value pada products_df

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik products_df

# %%
print("Jumlah duplikasi data pada products_df: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi data pada products_df:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# ...

# %% [markdown]
# Menilai data sellers

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# Mengecek adanya duplikasi data dan menampilkan paramter statistik sellers_df

# %%
print("Jumlah duplikasi data pada sellers_df: ", sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi data pada sellers_df:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
#
# |   | Tipe data | Missing Value | Duplicate Data |
# |---|---|---|---|
# | customers_df | - | - | - |
# | geoloc_df | - | - |  Terdapat 261831 data yang duplikat |
# | order_items_df | Terdapat kesalahan tipe data untuk kolom shipping_limit_date | - | - |
# | order_payments_df | - | - | - |
# | order_reviews_df | Terdapat kesalahan tipe data untuk kolom review_creation_date dan review_answer_timestamp | Terdapat 87656 missing values pada kolom review_comment_title & 58247 missing values pada review_comment_message | - |
# | orders_df | Terdapat kesalahan tipe data untuk kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date | Terdapat 160 missing values pada order_approved_at, 1783 missing values pada order_delivered_carrier_date, dan 2965 pada order_delivered_customer_date | - |
# | product_category_df | - | - | - |
# | products_df | - | Terdapat masing-masing 610 missing values pada product_category_name, product_name_lenght, product_description_lenght, product_photos_qty dan terdapat masing-masing 2 missing values pada product_weight_g, product_length_cm, product_height_cm, product_width_cm| - |
# | sellers_df | - | - | - |

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# > Mengatasi kesalahan tipe data untuk kolom shipping_limit_date

# %%
datetime_order_items_col = ['shipping_limit_date']

for column in datetime_order_items_col:
    order_items_df[column] = pd.to_datetime(order_items_df[column])

# %% [markdown]
# Memastikan kembali tipe data apakah telah sesuai

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# ##### Membersihkan data order_reviews_df

# %% [markdown]
# > Mengatasi kesalahan tipe data pada order_reviews_df

# %%
datetime_order_reviews_col = ['review_creation_date', 'review_answer_timestamp']

for column in datetime_order_reviews_col:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %% [markdown]
# Memeriksa kembali tipe data apakah sudah sesuai

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# > Mengatasi permasalahan missing values pada order_reviews_df

# %% [markdown]
# Menampilkan semua baris data yang memiliki missing value

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# Menggunakan nilai yang dominan sebagai pengganti missing value

# %%
order_reviews_df.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_reviews_df.review_comment_message.value_counts()
# Out:
# review_comment_message
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %% [markdown]
# Penggantian missing value dengan nilai yang dominan

# %%
order_reviews_df.fillna(value='Recomendo', inplace=True)

# %% [markdown]
# Memeriksa kembali apakah masih terdapat missing value atau tidak pada review_comment_title

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data orders_df

# %% [markdown]
# > Mengatasi kesalahan tipe data pada orders_df

# %%
datetime_orders_col = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']

for column in datetime_orders_col:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %% [markdown]
# Memeriksa kembali tipe data apakah sudah sesuai atau belum

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# > Mengatasi missing values pada orders_df

# %% [markdown]
# Menampilkan baris data yang memuat kolom yang berisi missing value

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %% [markdown]
# Menggantikan nilai dari missing value

# %%
for column in datetime_orders_col:
    orders_df[column].fillna(orders_df[column].mode()[0], inplace=True)

# %% [markdown]
# Memeriksa kembali apakah masing terdapat missing value atau tidak

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data product_df

# %% [markdown]
# > Mengatasi masalah missing values pada data product_df

# %% [markdown]
# Menampilkan sekaligus baris data yang mengandung missing values pada masing-masing kolom

# %%
products_df[products_df.product_category_name.isna()]

products_df[products_df.product_name_lenght.isna()]

products_df[products_df.product_description_lenght.isna()]

products_df[products_df.product_photos_qty.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# Mengisi nilai missing values

# %%
products_df['product_category_name'].fillna(products_df['product_category_name'].mode()[0], inplace=True)

products_df['product_name_lenght'].fillna(products_df['product_name_lenght'].mean(), inplace=True)

products_df['product_description_lenght'].fillna(products_df['product_description_lenght'].mean(), inplace=True)

products_df['product_photos_qty'].fillna(products_df['product_photos_qty'].mean(), inplace=True)

# %% [markdown]
# Menghapus baris yang mengandung missing value dan cek kembali apakah masing terdapat missing value atau tidak

# %%
products_df.dropna(inplace=True)

products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explorasi data customers_df

# %% [markdown]
# Melihat rangkuman parameter statistik dari data customers_df

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Melihat persebaran jumlah pelanggan berdasarkan kota

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: customer_id, dtype: int64

# %% [markdown]
# Melihat persebaran jumlah pelanggan berdasarkan negara bagian (state)

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explorasi data order_payments_df

# %% [markdown]
# Menampilkan ringkasan parameter statistik data order_payments_df

# %%
order_payments_df.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# Menganalisis jumlah pesanan unik berdasarkan tipe pembayaran kemudian menampilkan 10 tipe pembayaran teratas dengan pesanan unik terbanyak

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explorasi data orders_df

# %% [markdown]
# Membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order dengan menghitung selisih order_delivered_customer_date dan order_delivered_carrier_date

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time / 86400)

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### Eksplorasi data orders_df dan customers_df

# %% [markdown]
# Mengidentifikasi pelanggan yang belum pernah melakukan order dengan membuat kolom baru bernama "status"

# %%
customer_id_in_orders_df = orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Inactive")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 92940  30201265565f84bf08c3ebf808449612  0b7b2a76d32731ca8078fa8e4caa8a76
# 91060  fdc2fcf28f9250a76e69dacfaf652eb8  0d60ae009e0cfd8b0c96aa47625f20a4
# 91122  701b198fdef03adba781dc5fa1aab985  a0d06124a01ccd028adfc41be39bc581
# 70850  5da5779c14e22cdcfed01160d6165476  98d64cb8cf9878369a43bde681e16463
# 64353  3ff6172542ecaff2e23fbb3c5396dde4  5d3dfd890c69a21b2d4b7602814c71de
#
#        customer_zip_code_prefix   customer_city customer_state  status
# 92940                     13187     hortolandia             SP  Active
# 91060                     21830  rio de janeiro             RJ  Active
# 91122                     79740        ivinhema             MS  Active
# 70850                      2232       sao paulo             SP  Active
# 64353                     46800     ruy barbosa             BA  Active

# %% [markdown]
# Menampilkan informasi terkait jumlah pelanggan yang berstatus "Active" dan "Inactive"

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Melakukan merge terhadap data orders_df dan customers_df

# %% [markdown]
# Melakukan proses merge dengan metode "left"

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)

orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Menampilkan info jumlah order berdasarkan kota

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil tsb, diketahui bahwa kota Sao Paulo merupakan kota yang yang memiliki jumlah order terbanyak

# %% [markdown]
# Menampilkan info jumlah order berdasarkan state

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil tsb, diketahui bahwa SP merupakan state yang paling banyak melakukan order

# %% [markdown]
# Menampilkan info jumlah order berdasarkan kode pos

# %%
orders_customers_df.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
# 29101    101
# 13212     95
# 35162     93
# 22631     89
# 38400     87
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil tsb, diketahui bahwa kode pos 22790 merupakan kode pos yang paling banyak melakukan order

# %% [markdown]
# Menampilkan info jumlah order berdasarkan status order

# %%
orders_customers_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil tsb, diketahui bahwa status "delivered" merupakan status dengan jumlah order terbanyak

# %% [markdown]
# ### Melakukan merge terhadap data order_payments_df dan order_reviews_df

# %%
order_payments_reviews_df = pd.merge(
    left=order_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

order_payments_reviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %% [markdown]
# Menghitung jumlah pesanan unik utk setiap tipe pembayaran dan mendapatkan nilai min dan maks dari jumlah pembayaran

# %%
order_payments_reviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# ### Melakukan merge terhadap data orders_customers_df dan order_payments_reviews_df

# %%
customers_df = pd.merge(
    left=orders_customers_df,
    right=order_payments_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### Melakukan merge terhadap data order_items_df dan sellers_df

# %%
order_items_seller_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)

order_items_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %% [markdown]
# Menampilkan 10 kota dengan jumlah penjual terbanyak

# %%
order_items_seller_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %% [markdown]
# Menampilkan 10 negara bagian dengan jumlah penjual terbanyak

# %%
order_items_seller_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Melakukan merge terhadap data products_df dan product_category_df

# %%
product_df = pd.merge(
    left=products_df,
    right=product_category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)

product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Menampilkan 10 kategori produk dengan jumlah produk terbanyak

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3638
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %% [markdown]
# Menampilkan 10 kategori produk (dalam bahasa inggris) dengan jumlah produk terbanyak

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3638
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# ### Melakukan merge terhadap data product_df dan order_items_seller_df

# %%
sellers_df = pd.merge(
    left=product_df,
    right=order_items_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)

sellers_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Menampilkan jumlah pesanan serta harga min dan maks untuk setiap kategori produk dalam bahasa Inggris.

# %%
sellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price": ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Eksplorasi data geolocation

# %% [markdown]
# Menampilkan 5 sampel geoloc_df

# %%
geoloc_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 750398                        63605        -5.808902       -39.420848
# 234256                         9606       -23.673105       -46.559722
# 897166                        87302       -24.045342       -52.392526
# 648197                        38413       -18.923578       -48.314996
# 294226                        13190       -22.940182       -47.270512
#
#              geolocation_city geolocation_state
# 750398        piquet carneiro                CE
# 234256  sao bernardo do campo                SP
# 897166           campo mourao                PR
# 648197             uberlandia                MG
# 294226              monte mor                SP

# %%
# !pip install unidecode
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Membuat string yang bersih, tanpa spasi berlebih, tanpa karakter khusus, dan dalam format huruf kecil

# %%
import unidecode

def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %%
geoloc_df['geolocation_city'] = geoloc_df['geolocation_city'].apply(pretty_string)

geoloc_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geoloc_df[geoloc_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ### Melakukan merge terhadap data customers_df dan sellers_df

# %%
all_df = pd.merge(
    left=customers_df,
    right=sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

all_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Menampilkan total harga produk dan nilai pengiriman (freight_value) berdasarkan kota dan kategori produk

# %%
all_df.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              bed_bath_table                  29.90          16.79
#                     computers_accessories           69.90          20.98
#
# [25327 rows x 2 columns]

# %% [markdown]
# Menampilkan total harga produk dan nilai pengiriman (freight_value) berdasarkan state dan kategori produk

# %%
all_df.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  634.60         217.95
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5533.32        1393.53
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
# [1356 rows x 2 columns]

# %% [markdown]
# Menghitung jumlah pesanan dan total nilai pembayaran di setiap negara bagian lalu hasilnya diurutkan berdasarkan kolom payment_value sehingga negara bagian dengan total pembayaran tertinggi muncul di atas

# %%
all_df.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160067.46
# PR                  5045     1079708.45
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %% [markdown]
# Menghitung jumlah order lalu nilai minimum dan maksimum kolom review_score berdasarkan kategori produk dlm bhs Inggris

# %%
all_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   253          1.0  5.0
# art                                202          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              350          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2311          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4199          1.0  5.0
# toys                              3886          1.0  5.0
# watches_gifts                     5624          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa yang paling banyak dan paling sedikit terjual ?

# %%
sum_order_items_df = all_df.groupby(by="product_category_name_english").product_id.count().rename("product_qty").sort_values(ascending=False).reset_index()
sum_order_items_df.head(10)
# Out:
#   product_category_name_english  product_qty
# 0                bed_bath_table        13678
# 1                 health_beauty        10032
# 2                sports_leisure         9004
# 3               furniture_decor         8832
# 4         computers_accessories         8150
# 5                    housewares         7380
# 6                 watches_gifts         6213
# 7                     telephony         4726
# 8                  garden_tools         4590
# 9                          auto         4400

# %% [markdown]
# Data visualization :

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#FFA62F", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_qty", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="product_qty", y="product_category_name_english", data=sum_order_items_df.sort_values(by="product_qty", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Orders", fontsize=20)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3417003927.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_qty", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3417003927.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_qty", y="product_category_name_english", data=sum_order_items_df.sort_values(by="product_qty", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Pertanyaan 2: Bagaimana Demografi Pelanggan yang Kita Miliki ?

# %% [markdown]
# - Berdasarkan kota (city)

# %%
by_city_df = all_df['customer_city'].value_counts().head(10)


plt.figure(figsize=(10, 5))

most_city_order = by_city_df.idxmax()

by_city_df = by_city_df.sort_values(ascending=False)

colors_city = ["#FFA62F" if city == most_city_order else "#D3D3D3" for city in by_city_df.index]

sns.barplot(x=by_city_df.index,
            y=by_city_df.values,
            palette= colors_city
            )


plt.title("Number of Customers by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.xticks(rotation=45, fontsize=12 )
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\26279885.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=by_city_df.index,

# %% [markdown]
# - Berdasarkan negara bagian (state)

# %%
by_state_df = all_df.groupby(by="customer_state").customer_id.nunique().reset_index().sort_values(by="customer_id", ascending=False)

by_state_df.rename(columns={
    "customer_id" : "customer_count"
}, inplace=True)

by_state_df.head()
# Out:
#    customer_state  customer_count
# 25             SP           41746
# 18             RJ           12852
# 10             MG           11635
# 22             RS            5466
# 17             PR            5045

# %% [markdown]
# Data visualization :

# %%
plt.figure(figsize=(10, 5))

most_state_order = by_state_df["customer_count"].idxmax()

colors_state = ["#FFA62F" if state == most_state_order else "#D3D3D3" for state in by_state_df.index]

sns.barplot(x="customer_state",
            y="customer_count",
            data=by_state_df,
            palette=colors_state)

plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\237514116.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="customer_state",

# %% [markdown]
# - Berdasarkan order status :

# %%
order_status_total = all_df["order_status"].value_counts()

order_status_total
# Out:
# order_status
# delivered      115721
# shipped          1256
# canceled          750
# unavailable       652
# invoiced          378
# processing        376
# created             5
# approved            3
# Name: count, dtype: int64

# %% [markdown]
# Data visualization :

# %%
plt.figure(figsize=(10, 5))

order_status_total.plot(kind='bar', color=['#FFA62F', '#D3D3D3', '#D3D3D3', '#D3D3D3', '#D3D3D3'])


plt.title("Number of Customer by Order Status", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Metode pembayaran apa yang paling sering dan sedikit digunakan ?

# %%
by_payment_type_df = order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).reset_index()

by_payment_type_df.rename(columns={
    "order_id": "order_count"
}, inplace=True)

by_payment_type_df
# Out:
#   payment_type  order_count
# 0  credit_card        76505
# 1       boleto        19784
# 2      voucher         3866
# 3   debit_card         1528
# 4  not_defined            3

# %% [markdown]
# Data visualization :

# %%
colors_payment = ["#FFA62F" if payment == "credit_card" else "#D3D3D3" for payment in by_payment_type_df["payment_type"]]

plt.figure(figsize=(10, 5))

sns.barplot(
    y = "order_count",
    x = "payment_type",
    data = by_payment_type_df,
    palette=colors_payment
)

plt.title("Number of Orders by Payment Type", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\1297820146.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 4: Bagaimana performa penjualan dan revenue perusahaan per bulan (2016 - 2018) ?

# %%
monthly_orders_df = all_df.resample(rule="M", on="order_purchase_timestamp").agg({
    "order_id": "nunique",
    "price": "sum"
})

monthly_orders_df.index = monthly_orders_df.index.strftime("%Y-%m")
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)

monthly_orders_df.sort_values(by="order_count", ascending=False).head()

monthly_orders_df.sort_values(by="revenue", ascending=False).head()
# Out:
#    order_purchase_timestamp  order_count     revenue
# 14                  2017-11         7544  1055072.10
# 20                  2018-05         6873  1032699.42
# 19                  2018-04         6939  1031717.62
# 18                  2018-03         7211  1029589.67
# 16                  2018-01         7269   993701.49

# %% [markdown]
# Data Visualization :

# %%
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_orders_df["order_purchase_timestamp"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#FFA62F") 
plt.title("Number of Orders per Month (2016-2018)", loc="center", fontsize=20) 
plt.xticks(fontsize=10, rotation=90) 
plt.yticks(fontsize=10) 
plt.show()

# %%
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_orders_df["order_purchase_timestamp"], monthly_orders_df["revenue"], marker='o', linewidth=2, color="#FFA62F") 
plt.title("Total Revenue per Month (2016-2018)", loc="center", fontsize=20) 
plt.xticks(fontsize=10, rotation=90) 
plt.yticks(fontsize=10) 
plt.show()

# %% [markdown]
# ### Pertanyaan 5: Bagaimana tingkat kepuasan pengguna terhadap layanan yang diberikan ?

# %%
service_review_scores = all_df['review_score'].value_counts().sort_values(ascending=False)

most_review_score = service_review_scores.idxmax()

service_review_colors = ["#FFA62F" if score == most_review_score else "#D3D3D3" for score in service_review_scores.index]

plt.figure(figsize=(10, 5))
sns.barplot(
    x=service_review_scores.index,
    y=service_review_scores.values,
    order=service_review_scores.index,
    palette=service_review_colors
)

plt.title("Customer Rating For Service", loc="center", fontsize=15)
plt.ylabel("Total")
plt.xlabel("Rating")
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3992103497.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# Memeriksa isi dari all_df

# %%
all_df.sample(5)
# Out:
#                                 order_id                       customer_id  \
# 24247   5601fa41e5818b9941a6bdd21978b6ac  f52d6c5cdf9a2638cf24e11bd300c158
# 47007   24385282a9d0bd77f93f0dd5accbb592  a998044c2973100ce2dbc8caa859191e
# 101217  b3b663af930cb86b58bbebd928832b4c  d513bac7cc42bb5a6ee1acd1e1a3be62
# 60214   087a5caa838085de4baa54e02f8f2878  01621ab81b760e6e48e8eb3a300c77bf
# 65132   f2b150da2994a9a654a8af90977b9cc9  f079d438f007085c7450888abda83420
#
#        order_status order_purchase_timestamp   order_approved_at  \
# 24247     delivered      2018-08-20 23:35:44 2018-08-20 23:49:16
# 47007     delivered      2017-11-08 22:50:01 2017-11-09 22:47:08
# 101217    delivered      2018-06-27 09:34:06 2018-06-29 02:35:17
# 60214     delivered      2018-06-09 01:13:30 2018-06-09 01:36:26
# 65132     delivered      2018-07-20 11:28:01 2018-07-20 11:46:16
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %% [markdown]
# **RFM Analysis** (Mengelompokkan pelanggan ke dalam kategori berdasarkan parameter Recency, Frequency, dan Monetary)
# - Recency: parameter yang digunakan untuk melihat kapan terakhir seorang pelanggan melakukan transaksi.
#
# - Frequency: parameter ini digunakan untuk mengidentifikasi seberapa sering seorang pelanggan melakukan transaksi.
#
# - Monetary: parameter terakhir ini digunakan untuk mengidentifikasi seberapa besar revenue yang berasal dari pelanggan tersebut.

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "price": "sum" # menghitung jumlah revenue yang dihasilkan
})


rfm_df.columns = ["customer_id", "last_purchase_date", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df['last_purchase_date'] = rfm_df["last_purchase_date"].dt.date
recent_date = orders_df['order_purchase_timestamp'].dt.date.max()
rfm_df['recency'] = rfm_df['last_purchase_date'].apply(lambda x: (recent_date - x).days)


rfm_df.drop("last_purchase_date", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      337
# 1  000161a058600d5901f007fab4c27140          1     54.90      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      596
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      427
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      198

# %% [markdown]
# Data Visualization :

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(45, 12))  # Increased height for more space

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

# Plot by Recency
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=14, rotation=30)
for label in ax[0].get_xticklabels():
    label.set_ha('right')  # Align labels to the right

# Plot by Frequency
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=14, rotation=30)
for label in ax[1].get_xticklabels():
    label.set_ha('right')

# Plot by Monetary
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=14, rotation=30)
for label in ax[2].get_xticklabels():
    label.set_ha('right')

# Set supertitle and adjust layout
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.subplots_adjust(bottom=0.3, wspace=0.4)  # Added space at the bottom for x-ticks and between subplots
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3503220240.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3503220240.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# C:\Users\HP\AppData\Local\Temp\ipykernel_10960\3503220240.py:24: FutureWarning:
#
# ...

# %% [markdown]
# > Berdasarkan visualisasi data tersebut, kita dapat melihat beberapa pelanggan terbaik berdasarkan ketiga parameter (recency, frequency, dan monetary)

# %% [markdown]
# Menyimpan berkas data yang telah dibersihkan (dalam format .csv)

# %%
all_df.to_csv('./dashboard/all_data.csv', index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Kesimpulan pertanyaan 1 : Produk apa yang paling banyak dan paling sedikit terjual ?
#     > Berdasarkan visualisasi data di atas, terlihat bahwa :
#     - Produk yang terjual paling banyak adalah bed_bath_table
#     - Produk yang paling sedikit terjual adalah security_and_services.
#
# - Kesimpulan pertanyaan 2 : Bagaimana demografi pelanggan yang kita miliki ?
#     > Berdasarkan visualisasi data di atas, terlihat bahwa :
#     - Jumlah pelanggan terbanyak berada di kota Sao Paulo
#     - Jumlah pelanggan terbanyak berada pada state SP
#     - Status pemesanan terbanyak adalah "delivered"
#
# - Kesimpulan pertanyaan 3 : Metode pembayaran apa yang paling sering dan sedikit digunakan ?
#     > Berdasarkan visualisasi di atas, metode pembayaran yang paling banyak digunakan adalah Credit Card
#
# - Kesimpulan pertanyaan 4 : Bagaimana performa penjualan dan revenue perusahaan per bulan (2016 - 2018) ?
#     > Berdasarkan visualisasi data di atas, terlihat bahwa :
#     - Jumlah order dan revenue terbanyak terjadi pada bulan November 2017
#     - Adanya penurunan jumlah order dan revenue yang cukup signifikan pada bulan September 2018
#
#
# - Kesimpulan pertanyaan 5 : Bagaimana tingkat kepuasan pengguna terhadap layanan yang diberikan ?
#     > Berdasarkan visualisasi data di atas, terlihat bahwa tingkat kepuasan pengguna terbanyak mencapai rating 5.0
